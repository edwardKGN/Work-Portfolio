# %%
from analysisModule.sectorAnalysis_finance import sectorAnalysis_finance

# %%
MB = sectorAnalysis_finance("FR_Maybank_Finance.xlsx", "output", 0)
MB.getFinancialRatios()
# Out:
#                                          2020       2019       2018  \
# Financial Ratios
# Price to Book Ratio                  1.063054   1.257562   1.478085
# Price to Earnings Ratio             14.154023  11.459299  12.562566
# Return on Equity                     0.079575   0.103905   0.110924
# Return on Capital Employed           0.067120   0.081291   0.075300
# EBITDA to Revenue Ratio              0.610712   0.638152   0.666935
# EBITDA to Cash Conversion Ratio      0.072135  -0.295461   0.336031
# Revenue to Expense Ratio             2.616228   2.240352   2.115662
# Current Ratio                        0.367700   0.384834   0.400402
# Cash Ratio                           0.065939   0.070366   0.088902
# Operating Cash Flow Ratio            0.003383  -0.014827   0.016516
# Cash Conversion Ratio                0.334587  -1.176094   1.269146
# Dividend Yield                       0.061466   0.074074   0.060000
# ...

# %%
MB.analyse_finance()
# Out:
# Analysing Finance's Fundamentals
# Analysing Valuation Ratios
# Analyse Profitability Ratios
# Analysing Efficiency Ratios
# Analysing Liquidity Ratios
# Checking for Dividend Paying Ratios
# Analyising Dividend Paying Ratios
# Checking for Sales Ratios
# Checking for Inventory Ratios

# %%
MB.getAnalysis(0)
# Out:
#           Financial Ratios Condition     2020     2019     2018     2017  \
# 0      Price to Book Ratio     <=1.3      Met      Met  Not Met  Not Met
# 1  Price to Earnings Ratio      >=10      Met      Met      Met      Met
# 2            Current Ratio       >=2  Not Met  Not Met  Not Met  Not Met
# 3    Cash Conversion Ratio       >=1  Not Met  Not Met      Met  Not Met
# 4           Dividend Yield    >=0.03      Met      Met      Met      Met
# 5  Dividend Coverage Ratio       >=1      Met      Met      Met      Met
# 6    Dividend Payout Ratio       <=1      Met      Met      Met      Met
# 7         Return on Assets    >=0.01  Not Met      Met      Met      Met
# 8           Leverage Ratio    >=0.03      Met      Met      Met      Met
# 9   Capital Adequacy Ratio    >=0.08      Met      Met      Met      Met
#
#       2016
# 0  Not Met
# 1      Met
# 2  Not Met
# 3  Not Met
# 4      Met
# 5      Met
# 6      Met
# 7  Not Met
# 8      Met
# 9      Met

# %%
MB.getAnalysis(1)
# Out:
#                       Financial Ratios    Growth   Intercept  \
# 0                  Price to Book Ratio -0.080858  164.505524
# 1              Price to Earnings Ratio  0.220938 -433.107172
# 2                     Return on Equity -0.004705    9.594407
# 3           Return on Capital Employed  0.005911  -11.863086
# 4              EBITDA to Revenue Ratio -0.005758   12.258299
# 5      EBITDA to Cash Conversion Ratio  -0.01044    21.09509
# 6             Revenue to Expense Ratio  0.087911 -175.135407
# 7                        Current Ratio -0.026198   53.282202
# 8                           Cash Ratio  -0.00976   19.780208
# 9            Operating Cash Flow Ratio -0.000509    1.028956
# 10               Cash Conversion Ratio  -0.02857   57.755762
# 11                      Dividend Yield  0.001405   -2.773041
# 12             Dividend Coverage Ratio  -0.04654   95.174029
# 13               Dividend Payout Ratio  0.030592  -60.935374
# ...

# %%
MB.writeOut("FA_Maybank_Finance")
