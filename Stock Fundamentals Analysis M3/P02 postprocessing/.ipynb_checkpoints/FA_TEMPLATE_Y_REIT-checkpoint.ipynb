# %%
from analysisModule.sectorAnalysis_REIT import sectorAnalysis_REIT

# %%
Y = sectorAnalysis_REIT("FR_Y_REIT", "output", 0)
Y.getFinancialRatios()
# Out:
#                                             2020          2019          2018  \
# Financial Ratios
# EBITDA to Cash Conversion Ratio         1.079302      0.911594      0.945194
# Revenue to Expense Ratio                2.079185      2.008129      1.850357
# Current Ratio                           0.033836      0.022965      0.026528
# Cash Ratio                              0.007235      0.008192      0.009131
# Operating Cash Flow Ratio               0.060677      0.142107      0.121351
# Cash Conversion Ratio                   1.306326      1.215512      1.361947
# Debt Ratio                              0.399142      0.335818      0.340015
# Debt to Equity Ratio                    0.718171      0.542371      0.548623
# Interest Coverage Ratio                 4.743344      4.058742      3.311929
# Years to Repay Debt                    16.738342      5.774538      7.099900
# Average Interest Rate                   0.012595      0.042667      0.042527
# ...

# %%
Y.analyse_REIT()
# Out:
# Analysing REIT's Fundamentals
# Analysing Efficiency Ratios
# Analysing Liquidity Ratios
# Analysing Solvency Ratios
# Checking for Dividend Paying Ratios
# Analyising Dividend Paying Ratios
# Checking for Sales Ratios
# Checking for Inventory Ratios

# %%
Y.getAnalysis(0)
# Out:
#           Financial Ratios Condition     2020     2019     2018     2017  \
# 0            Current Ratio       >=2  Not Met  Not Met  Not Met  Not Met
# 1    Cash Conversion Ratio       >=1      Met      Met      Met      Met
# 2               Debt Ratio     <=0.5      Met      Met      Met      Met
# 3     Debt to Equity Ratio    <=0.33  Not Met  Not Met  Not Met  Not Met
# 4  Interest Coverage Ratio       >=1      Met      Met      Met      Met
# 5    Average Interest Rate    <=0.03      Met  Not Met  Not Met  Not Met
# 6           Dividend Yield    >=0.03      Met      Met      Met      Met
# 7  Dividend Coverage Ratio       >=1  Not Met      Met      Met  Not Met
# 8    Dividend Payout Ratio       <=1  Not Met      Met      Met  Not Met
#
#       2016
# 0  Not Met
# 1  Not Met
# 2      Met
# 3  Not Met
# 4      Met
# 5  Not Met
# 6      Met
# 7      Met
# 8      Met

# %%
Y.getAnalysis(1)
# Out:
#                       Financial Ratios     Growth     Intercept  \
# 0      EBITDA to Cash Conversion Ratio   -0.03335     68.400373
# 1             Revenue to Expense Ratio   0.050465    -99.877894
# 2                        Current Ratio  -0.003362      6.816901
# 3                           Cash Ratio  -0.000686      1.393974
# 4            Operating Cash Flow Ratio  -0.018384     37.226486
# 5                Cash Conversion Ratio   -0.04071     83.628085
# 6                           Debt Ratio   0.034315    -68.927226
# 7                 Debt to Equity Ratio   0.082507   -165.983948
# 8              Interest Coverage Ratio   0.442554   -889.470427
# 9                  Years to Repay Debt   1.966721  -3960.090714
# 10               Average Interest Rate   -0.00892     18.039524
# 11                      Dividend Yield  -0.000453      0.979979
# 12             Dividend Coverage Ratio  -0.115664    234.367002
# 13               Dividend Payout Ratio   0.089047     -178.4766
# ...

# %%
Y.writeOut("FA_Y_REIT")
