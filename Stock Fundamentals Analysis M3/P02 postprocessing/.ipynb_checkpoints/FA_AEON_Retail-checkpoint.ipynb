# %%
from analysisModule.fundamentalsAnalysis import FA

# %%
AEON = FA("FR_AEON_retail.xlsx", "output", 0)
AEON.getFinancialRatios()
# Out:
#                                        2019       2018       2017       2016  \
# Financial Ratios
# Price to Book Ratio                1.181904   1.028048   1.268274   1.938123
# Price to Earnings Ratio           18.207736  19.619552  23.499426  39.710592
# Return on Equity                   0.064454   0.052031   0.053497   0.048297
# Return on Capital Employed         0.088192   0.100361   0.134854   0.088108
# EBITDA to Revenue Ratio            0.186084   0.122649   0.128612   0.115419
# EBITDA to Cash Conversion Ratio    0.815879   1.055791   0.732683   1.040392
# Revenue to Expense Ratio           1.151643   1.107596   1.134005   1.105164
# Current Ratio                      0.360485   0.367852   0.296352   0.386837
# Cash Ratio                         0.027116   0.036376   0.029931   0.037535
# Operating Cash Flow Ratio          0.278963   0.249625   0.146709   0.222281
# Cash Conversion Ratio              6.305137   5.362880   3.668660   5.309246
# ...

# %%
AEON.getAnalysis(0)
# Out:
# Empty DataFrame
# Columns: [Financial Ratios, Condition, 2019, 2018, 2017, 2016, 2015]
# Index: []

# %%
AEON.getAnalysis(1)
# Out:
# Empty DataFrame
# Columns: [Financial Ratios, Growth, Intercept, Correlation Coefficient, Growth Uncertainty, Intercept Uncertainty]
# Index: []

# %%
AEON.getFinancialYears()
# Out:
# array([2019, 2018, 2017, 2016, 2015], dtype=int64)

# %%
AEON.getFinancialRatios_row("Price to Book Ratio")
# Out:
# array([1.18190393, 1.02804818, 1.26827445, 1.93812349, 2.09248044])

# %%
AEON.setFinancialRatiosQuality("Price to Book Ratio", 2, 1.3)

# %%
AEON.getAnalysis(0)
# Out:
#       Financial Ratios Condition     2019     2018     2017 2016 2015
# 0  Price to Book Ratio     >=1.3  Not Met  Not Met  Not Met  Met  Met

# %%
AEON.setFinancialRatiosGrowth("Price to Book Ratio")

# %%
AEON.getAnalysis(1)
# Out:
#       Financial Ratios    Growth  Intercept Correlation Coefficient  \
# 0  Price to Book Ratio -0.273123  552.39052               -0.900171
#
#   Growth Uncertainty Intercept Uncertainty
# 0           0.076295            153.887671

# %%
AEON.writeOut("FA_AEON_Retail")

# %%
from analysisModule.FA_Valuation import FA_Valuation

# %%
AEON = FA_Valuation("FR_AEON_retail.xlsx", "output", 0)

# %%
AEON.analyse_valuation()
# Out:
# Analysing Valuation Ratios

# %%
AEON.getAnalysis(0)
# Out:
#           Financial Ratios Condition 2019 2018 2017     2016     2015
# 0      Price to Book Ratio     <=1.3  Met  Met  Met  Not Met  Not Met
# 1  Price to Earnings Ratio      >=10  Met  Met  Met      Met      Met

# %%
AEON.getAnalysis(1)
# Out:
#           Financial Ratios    Growth    Intercept Correlation Coefficient  \
# 0      Price to Book Ratio -0.273123    552.39052               -0.900171
# 1  Price to Earnings Ratio -4.171666  8440.262158               -0.755635
#
#   Growth Uncertainty Intercept Uncertainty
# 0           0.076295            153.887671
# 1           2.087724           4210.940481

# %%
from analysisModule.sectorAnalysis_retail import sectorAnalysis_retail

# %%
AEON = sectorAnalysis_retail("FR_AEON_retail.xlsx", "output", 0)
AEON.getFinancialRatios()
# Out:
#                                        2019       2018       2017       2016  \
# Financial Ratios
# Price to Book Ratio                1.181904   1.028048   1.268274   1.938123
# Price to Earnings Ratio           18.207736  19.619552  23.499426  39.710592
# Return on Equity                   0.064454   0.052031   0.053497   0.048297
# Return on Capital Employed         0.088192   0.100361   0.134854   0.088108
# EBITDA to Revenue Ratio            0.186084   0.122649   0.128612   0.115419
# EBITDA to Cash Conversion Ratio    0.815879   1.055791   0.732683   1.040392
# Revenue to Expense Ratio           1.151643   1.107596   1.134005   1.105164
# Current Ratio                      0.360485   0.367852   0.296352   0.386837
# Cash Ratio                         0.027116   0.036376   0.029931   0.037535
# Operating Cash Flow Ratio          0.278963   0.249625   0.146709   0.222281
# Cash Conversion Ratio              6.305137   5.362880   3.668660   5.309246
# ...

# %%
AEON.analyse_retail()
# Out:
# Analysing Valuation Ratios
# Analyse Profitability Ratios
# Analysing Efficiency Ratios
# Analysing Liquidity Ratios
# Analysing Solvency Ratios
# Checking for Dividend Paying Ratios
# Analyising Dividend Paying Ratios
# Checking for Sales Ratios
# Analyising Sales Ratios
# Checking for Inventory Ratios
# Analysing Inventory Ratios

# %%
AEON.getAnalysis(0)
# Out:
#            Financial Ratios Condition     2019     2018     2017     2016  \
# 0       Price to Book Ratio     <=1.3      Met      Met      Met  Not Met
# 1   Price to Earnings Ratio      >=10      Met      Met      Met      Met
# 2             Current Ratio       >=2  Not Met  Not Met  Not Met  Not Met
# 3     Cash Conversion Ratio       >=1      Met      Met      Met      Met
# 4                Debt Ratio     <=0.5      Met      Met      Met      Met
# 5      Debt to Equity Ratio    <=0.33  Not Met  Not Met  Not Met  Not Met
# 6   Interest Coverage Ratio       >=1      Met      Met      Met      Met
# 7     Average Interest Rate    <=0.03  Not Met  Not Met  Not Met  Not Met
# 8            Dividend Yield    >=0.03  Not Met  Not Met  Not Met  Not Met
# 9   Dividend Coverage Ratio       >=1      Met      Met      Met      Met
# 10    Dividend Payout Ratio       <=1      Met      Met      Met      Met
#
#        2015
# 0   Not Met
# 1       Met
# 2   Not Met
# 3       Met
# ...

# %%
AEON.getAnalysis(1)
# Out:
#                    Financial Ratios     Growth     Intercept  \
# 0               Price to Book Ratio  -0.273123     552.39052
# 1           Price to Earnings Ratio  -4.171666   8440.262158
# 2                  Return on Equity  -0.001098      2.273488
# 3        Return on Capital Employed  -0.004399      8.978119
# 4           EBITDA to Revenue Ratio   0.014666    -29.447747
# 5   EBITDA to Cash Conversion Ratio   0.031667    -63.010944
# 6          Revenue to Expense Ratio   0.009973    -18.995011
# 7                     Current Ratio  -0.018926     38.546138
# 8                        Cash Ratio  -0.015151     30.605916
# 9         Operating Cash Flow Ratio   0.030129    -60.562892
# 10            Cash Conversion Ratio   0.815493  -1640.268535
# 11                       Debt Ratio  -0.010132     20.632118
# 12             Debt to Equity Ratio   0.024028    -47.975463
# 13          Interest Coverage Ratio   -3.81101    7700.25786
# ...

# %%
AEON.writeOut("FA_AEON")
