# %%
from analysisModule.sectorAnalysis_propDev import sectorAnalysis_propDev

# %%
uoaDev = sectorAnalysis_propDev("FR_UOADev_PropDev.xlsx", "output", 0)
uoaDev.getFinancialRatios()
# Out:
#                                        2020       2019        2018  \
# Financial Ratios
# Price to Book Ratio                0.641615   0.756847    0.790564
# Price to Earnings Ratio            8.980995   9.769307    9.499560
# Return on Equity                   0.073776   0.080638    0.087935
# Return on Capital Employed         0.063781   0.077141    0.099586
# EBITDA to Revenue Ratio            0.441592   0.439817    0.405331
# EBITDA to Cash Conversion Ratio    1.041315   1.172213    0.595874
# Revenue to Expense Ratio           3.017808   3.299053    3.939966
# Current Ratio                      6.787374   4.934298    4.107330
# Cash Ratio                         3.293598   1.556916    0.774535
# Operating Cash Flow Ratio          0.726611   0.939877    0.409724
# Cash Conversion Ratio              0.971589   1.394178    0.741527
# Debt Ratio                         0.000000   0.009056    0.012778
# Debt to Equity Ratio               0.000000   0.010243    0.014962
# ...

# %%
uoaDev.analyse_propDev()
# Out:
# Analyzing Property Development's Fundamentals Analysis
# Analysing Valuation Ratios
# Analyse Profitability Ratios
# Analysing Efficiency Ratios
# Analysing Liquidity Ratios
# Analysing Solvency Ratios
# Checking for Dividend Paying Ratios
# Analyising Dividend Paying Ratios
# Checking for Sales Ratios
# Analyising Sales Ratios
# Checking for Inventory Ratios

# %%
uoaDev.getAnalysis(0)
# Out:
#            Financial Ratios Condition     2020     2019     2018     2017  \
# 0       Price to Book Ratio     <=1.3      Met      Met      Met      Met
# 1   Price to Earnings Ratio      >=10  Not Met  Not Met  Not Met  Not Met
# 2             Current Ratio       >=2      Met      Met      Met      Met
# 3     Cash Conversion Ratio       >=1  Not Met      Met  Not Met  Not Met
# 4                Debt Ratio     <=0.5      Met      Met      Met      Met
# 5      Debt to Equity Ratio    <=0.33      Met      Met      Met      Met
# 6   Interest Coverage Ratio       >=1      Met      Met      Met      Met
# 7     Average Interest Rate    <=0.03      Met  Not Met  Not Met  Not Met
# 8            Dividend Yield    >=0.03      Met      Met      Met      Met
# 9   Dividend Coverage Ratio       >=1      Met      Met      Met      Met
# 10    Dividend Payout Ratio       <=1      Met      Met      Met      Met
#
#        2016
# 0       Met
# 1   Not Met
# 2       Met
# 3   Not Met
# ...

# %%
uoaDev.getAnalysis(1)
# Out:
#                    Financial Ratios     Growth     Intercept  \
# 0               Price to Book Ratio  -0.081312    164.901165
# 1           Price to Earnings Ratio   0.928497  -1865.448271
# 2                  Return on Equity  -0.026971       54.5383
# 3        Return on Capital Employed  -0.017713     35.842374
# 4           EBITDA to Revenue Ratio  -0.038706     78.599702
# 5   EBITDA to Cash Conversion Ratio   0.202162   -407.266166
# 6          Revenue to Expense Ratio   0.159099   -317.914302
# 7                     Current Ratio   0.892446  -1796.469195
# 8                        Cash Ratio   0.569383  -1147.577116
# 9         Operating Cash Flow Ratio   0.161689   -325.785439
# 10            Cash Conversion Ratio   0.234416    -472.31431
# 11                       Debt Ratio  -0.001783       3.60614
# 12             Debt to Equity Ratio  -0.002288      4.627151
# 13          Interest Coverage Ratio    46.1351 -92951.364297
# ...

# %%
uoaDev.writeOut("FA_UOADev_propDev")
