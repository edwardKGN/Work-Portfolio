# %%
from analysisModule.sectorAnalysis_utilities import sectorAnalysis_utilities

# %%
TnB = sectorAnalysis_utilities("FR_TnB_Utilities.xlsx", "output", 0) 
TnB.getFinancialRatios()
# Out:
#                                       2020       2019       2018        2017  \
# Financial Ratios
# Price to Book Ratio               1.042560   1.277221   1.315084    1.400341
# Price to Earnings Ratio          16.436924  16.964712  20.651986   31.017935
# Return on Equity                  0.064771   0.076662   0.064750    0.045678
# Return on Capital Employed        0.048213   0.052932   0.052116    0.023918
# EBITDA to Revenue Ratio           2.349031   1.854320   1.651541    4.775290
# EBITDA to Cash Conversion Ratio   0.150227   0.205995   0.156628    0.029588
# Revenue to Expense Ratio          1.073680   1.076725   1.060192    1.096138
# Current Ratio                     0.965321   1.081989   1.412729    1.519594
# Cash Ratio                        0.174402   0.102546   0.349103    0.267365
# Operating Cash Flow Ratio         0.538816   0.817485   0.598885    0.121590
# Cash Conversion Ratio             4.291174   4.377435   3.480748    0.849990
# ...

# %%
TnB.analyse_utilities()
# Out:
# Analysing Utilities's Fundamentals
# Analysing Valuation Ratios
# Analyse Profitability Ratios
# Analysing Efficiency Ratios
# Analysing Liquidity Ratios
# Analysing Solvency Ratios
# Checking for Dividend Paying Ratios
# Analyising Dividend Paying Ratios
# Checking for Sales Ratios
# Analyising Sales Ratios
# Checking for Inventory Ratios
# Analysing Inventory Ratios

# %%
TnB.getAnalysis(0)
# Out:
#            Financial Ratios Condition     2020     2019     2018     2017  \
# 0       Price to Book Ratio     <=1.3      Met      Met  Not Met  Not Met
# 1   Price to Earnings Ratio      >=10      Met      Met      Met      Met
# 2             Current Ratio       >=2  Not Met  Not Met  Not Met  Not Met
# 3     Cash Conversion Ratio       >=1      Met      Met      Met  Not Met
# 4                Debt Ratio     <=0.5      Met      Met      Met      Met
# 5      Debt to Equity Ratio    <=0.33  Not Met  Not Met  Not Met  Not Met
# 6   Interest Coverage Ratio       >=1      Met      Met      Met      Met
# 7     Average Interest Rate    <=0.03  Not Met  Not Met  Not Met      Met
# 8            Dividend Yield    >=0.03      Met      Met      Met      Met
# 9   Dividend Coverage Ratio       >=1  Not Met  Not Met      Met  Not Met
# 10    Dividend Payout Ratio       <=1  Not Met  Not Met      Met  Not Met
#
#        2016
# 0   Not Met
# 1       Met
# 2   Not Met
# 3       Met
# ...

# %%
TnB.getAnalysis(1)
# Out:
#                    Financial Ratios     Growth     Intercept  \
# 0               Price to Book Ratio  -0.121375    246.260278
# 1           Price to Earnings Ratio  -0.390553    807.423355
# 2                  Return on Equity  -0.011895     24.083213
# 3        Return on Capital Employed  -0.002988      6.080557
# 4           EBITDA to Revenue Ratio  -0.160708    326.773688
# 5   EBITDA to Cash Conversion Ratio   0.012405    -24.888705
# 6          Revenue to Expense Ratio  -0.008144     17.517744
# 7                     Current Ratio  -0.183391    371.411447
# 8                        Cash Ratio   -0.02782     56.365832
# 9         Operating Cash Flow Ratio   0.012064    -23.764885
# 10            Cash Conversion Ratio   0.847836  -1707.969686
# 11                       Debt Ratio   0.000054      0.167794
# 12             Debt to Equity Ratio    0.04813    -96.367224
# 13          Interest Coverage Ratio  -20.17793  40782.839148
# ...

# %%
TnB.writeOut("FA_TnB_utilities")
