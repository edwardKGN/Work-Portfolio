# %%
from analysisModule.sectorAnalysis_REIT import sectorAnalysis_REIT

# %%
uoaREIT = sectorAnalysis_REIT("FR_UOAREIT_REIT.xlsx", "output", 0)
uoaREIT.getFinancialRatios()
# Out:
#                                             2020          2019          2018  \
# Financial Ratios
# EBITDA to Cash Conversion Ratio         1.079302      1.728687      0.837505
# Revenue to Expense Ratio                2.079185      2.063974      1.798939
# Current Ratio                           0.033836      0.033282      0.045488
# Cash Ratio                              0.007235      0.008392      0.010568
# Operating Cash Flow Ratio               0.060677      0.175566      0.135868
# Cash Conversion Ratio                   1.306326      2.751218      0.742022
# Debt Ratio                              0.399142      0.262508      0.264222
# Debt to Equity Ratio                    0.718171      0.388930      0.382355
# Interest Coverage Ratio                 4.743344      2.682124      3.218884
# Years to Repay Debt                    16.738342      8.704620      5.439698
# Average Interest Rate                   0.012595      0.042832      0.057111
# ...

# %%
uoaREIT.analyse_REIT()
# Out:
# Analysing REIT's Fundamentals
# Analysing Efficiency Ratios
# Analysing Liquidity Ratios
# Analysing Solvency Ratios
# Checking for Dividend Paying Ratios
# Analyising Dividend Paying Ratios
# Checking for Sales Ratios
# Checking for Inventory Ratios

# %%
uoaREIT.getAnalysis(0)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-3d33f817fb16> in <module>
# ----> 1 uoaREIT.getOutput(0)
#
# AttributeError: 'sectorAnalysis_REIT' object has no attribute 'getOutput'

# %%
uoaREIT.getAnalysis(1)

# %%
uoaREIT.writeOut("FA_UOAREIT_REIT")
