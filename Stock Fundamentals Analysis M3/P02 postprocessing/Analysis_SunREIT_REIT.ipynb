# %%
from analysisModule.sectorAnalysis_REIT import sectorAnalysis_REIT

# %%
SunREIT = sectorAnalysis_REIT("FA_sunway_REIT.xlsx", "output", 0)

SunREIT.getInput()
# Out:
# Financial Data Object created
#                       Financial Ratios           2020           2019  \
# 0            EBITDA to Cash Conversion       0.872566       0.908768
# 1             Revenue to Expense Ratio       1.818174       1.940494
# 2                        Current Ratio       0.120712       0.030007
# 3                           Cash Ratio       0.029963       0.014454
# 4            Operating Cash Flow Ratio       0.101503       0.122166
# 5                Cash Conversion Ratio       1.656558       1.033812
# 6                           Debt Ratio       0.407310       0.378925
# 7                 Debt to Equity Ratio       0.722454       0.644480
# 8              Interest Coverage Ratio       3.396101       3.735527
# 9                  Years to Repay Debt       8.717744       7.033046
# 10               Average Interest Rate       0.033777       0.038063
# 11                      Dividend Yield       0.045247       0.051283
# ...

# %%
SunREIT.analyse_REIT()
# Out:
# Analysing Retail's Fundamentals
# Analysing Efficiency Ratios
# Analysing Liquidity Ratios
# Analysing Solvency Ratios
# Checking for Dividend Paying Ratios
# Analyising Dividend Paying Ratios
# Checking for Sales Ratios
# Checking for Inventory Ratios

# %%
SunREIT.getOutput(0)
# Out:
#           Financial Ratios Condition   2020   2019   2018   2017   2016
# 0            Current Ratio       >=2  False  False  False  False  False
# 1    Cash Conversion Ratio       >=1   True   True  False  False   True
# 2               Debt Ratio     <=0.5   True   True   True   True   True
# 3     Debt to Equity Ratio    <=0.33  False  False  False  False  False
# 4  Interest Coverage Ratio       >=1   True   True   True   True   True
# 5    Average Interest Rate    <=0.03  False  False  False  False  False
# 6           Dividend Yield    >=0.03   True   True   True   True   True
# 7  Dividend Coverage Ratio       >=1  False   True   True   True   True
# 8    Dividend Payout Ratio       <=1  False   True   True   True   True

# %%
SunREIT.getOutput(1)
# Out:
#                       Financial Ratios     Growth     Intercept  \
# 0            EBITDA to Cash Conversion   -0.03489     71.353722
# 1             Revenue to Expense Ratio  -0.039149     80.946626
# 2                        Current Ratio   0.002331     -4.627272
# 3                           Cash Ratio  -0.010454      21.13167
# 4            Operating Cash Flow Ratio  -0.052623    106.364442
# 5                Cash Conversion Ratio    0.13075   -262.749208
# 6                           Debt Ratio   0.018547    -37.058566
# 7                 Debt to Equity Ratio   0.045887    -91.975151
# 8              Interest Coverage Ratio  -0.171612    350.125066
# 9                  Years to Repay Debt   0.567686  -1138.457049
# 10               Average Interest Rate  -0.001177      2.411388
# 11                      Dividend Yield  -0.002045      4.179198
# 12             Dividend Coverage Ratio   -0.06669    135.904555
# 13               Dividend Payout Ratio   0.049724    -99.564059
# ...

# %%
SunREIT.writeOutput("SunREIT_REIT")
