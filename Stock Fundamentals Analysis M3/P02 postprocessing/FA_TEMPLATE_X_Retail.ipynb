# %%
from analysisModule.sectorAnalysis_retail import sectorAnalysis_retail

# %%
X = sectorAnalysis_retail("FR_X_Retail", "output", 0)
X.getFinancialRatios()
# Out:
#                                       2019        2018       2017       2016  \
# Financial Ratios
# Price to Book Ratio               1.938123    1.181904   1.268274   2.092480
# Price to Earnings Ratio          39.710592   18.207736  23.499426  29.020546
# Return on Equity                  0.048297    0.064454   0.053497   0.071813
# Return on Capital Employed        0.088108    0.088192   0.134854   0.116312
# EBITDA to Revenue Ratio           0.115419    0.186084   0.128612   0.116368
# EBITDA to Cash Conversion Ratio   1.040392    0.815879   0.732683   0.665242
# Revenue to Expense Ratio          1.105164    1.151643   1.134005   1.102995
# Current Ratio                     0.386837    0.360485   0.296352   0.445625
# Cash Ratio                        0.037535    0.027116   0.029931   0.102291
# Operating Cash Flow Ratio         0.222281    0.278963   0.146709   0.141988
# Cash Conversion Ratio             5.309246    6.305137   3.668660   2.254490
# ...

# %%
X.analyse_retail()
# Out:
# Analyzing Retail Sector's Fundamentals Analysis
# Analysing Valuation Ratios
# Analyse Profitability Ratios
# Analysing Efficiency Ratios
# Analysing Liquidity Ratios
# Analysing Solvency Ratios
# Checking for Dividend Paying Ratios
# Analyising Dividend Paying Ratios
# Checking for Sales Ratios
# Analyising Sales Ratios
# Checking for Inventory Ratios
# Analysing Inventory Ratios

# %%
X.getAnalysis(0)
# Out:
#            Financial Ratios Condition     2019     2018     2017     2016  \
# 0       Price to Book Ratio     <=1.3  Not Met      Met      Met  Not Met
# 1   Price to Earnings Ratio      >=10      Met      Met      Met      Met
# 2             Current Ratio       >=2  Not Met  Not Met  Not Met  Not Met
# 3     Cash Conversion Ratio       >=1      Met      Met      Met      Met
# 4                Debt Ratio     <=0.5      Met      Met      Met      Met
# 5      Debt to Equity Ratio    <=0.33  Not Met  Not Met  Not Met  Not Met
# 6   Interest Coverage Ratio       >=1      Met      Met      Met      Met
# 7     Average Interest Rate    <=0.03  Not Met  Not Met  Not Met      Met
# 8            Dividend Yield    >=0.03  Not Met  Not Met  Not Met  Not Met
# 9   Dividend Coverage Ratio       >=1      Met      Met      Met      Met
# 10    Dividend Payout Ratio       <=1      Met      Met      Met      Met
#
#        2015
# 0       Met
# 1       Met
# 2   Not Met
# 3       Met
# ...

# %%
X.getAnalysis(1)
# Out:
#                    Financial Ratios    Growth    Intercept  \
# 0               Price to Book Ratio  0.090957  -181.959332
# 1           Price to Earnings Ratio  2.936927 -5897.770145
# 2                  Return on Equity -0.001483     3.048738
# 3        Return on Capital Employed -0.005263    10.720406
# 4           EBITDA to Revenue Ratio  0.005525   -11.011076
# 5   EBITDA to Cash Conversion Ratio  0.011984   -23.309161
# 6          Revenue to Expense Ratio  0.004378    -7.711017
# 7                     Current Ratio -0.004717     9.885704
# 8                        Cash Ratio -0.007286    14.742031
# 9         Operating Cash Flow Ratio  0.008229   -16.389496
# 10            Cash Conversion Ratio  0.394338  -790.799516
# 11                       Debt Ratio  -0.00394     8.142609
# 12             Debt to Equity Ratio  0.017086   -33.972755
# 13          Interest Coverage Ratio -1.877628  3800.627469
# 14              Years to Repay Debt -0.019148    40.331807
# ...

# %%
X.writeOut("FA_X_Retail")
