# %%
from financialRatiosModule.Sector_REIT import financialData_REIT

# %%
uoaREIT = financialData_REIT("uniqueItemsFromAnnualReports_UOAREIT_REIT.xlsx", "Main", 0)
uoaREIT.getInput()
# Out:
# Financial Data Object created
#                                                    2020          2019  \
# Items
# Cash and Cash Equivalent                   5.413230e+03  2.608717e+03
# Free Cash Flow                             2.804513e+03 -7.118790e+02
# Net Cash Flow from Operations              4.539596e+04  5.457368e+04
# Net Cash Flow from Investments            -7.002830e+05 -1.247111e+03
# Net Cash Flow from Financing               6.576915e+05 -5.403845e+04
# Gross Dividend Payout (Currency per Unit)  8.440000e-02  9.110000e-02
# Unit Price (Currency)                      1.130000e+00  1.230000e+00
# Depreciation                              -1.597900e+03  1.147170e+02
# Capital Expenditure                        0.000000e+00  1.140241e+03
# Total Debt                                 7.040225e+05  2.748000e+05
# Total Interest Paid                        8.867261e+03  1.177031e+04
# Total Assets                               1.763840e+06  1.046826e+06
# ...

# %%
# uoaREIT.analyze_REIT()
# Out:
# Analyzing Retail Sector's Financial Ratios
# Analyze Efficiency
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# D:\Programs\Anaconda\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Interest Expense'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
# Get Input Row, Return 0 if row not found

# %%
uoaREIT.getFinancialRatios()
