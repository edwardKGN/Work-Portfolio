# %%
from financialRatiosModule.Sector_REIT import financialData_REIT

# %%
Y = financialData_REIT("uniqueItemsFromAnnualReports_Y_REIT", "Main", 0)
Y.getInput()
# Out:
# Financial Data Object created
#                                                    2020          2019  \
# Items
# Cash and Cash Equivalent                   5.413230e+03  3.477706e+03
# Free Cash Flow                             2.804513e+03  5.660790e+02
# Net Cash Flow from Operations              4.539596e+04  6.032788e+04
# Net Cash Flow from Investments            -7.002830e+05 -1.131398e+03
# Net Cash Flow from Financing               6.576915e+05 -5.863041e+04
# Gross Dividend Payout (Currency per Unit)  8.440000e-02  1.048000e-01
# Unit Price (Currency)                      1.130000e+00  1.760000e+00
# Depreciation                              -1.597900e+03  7.766000e+01
# Capital Expenditure                        0.000000e+00  1.138784e+03
# Total Debt                                 7.040225e+05  3.821500e+05
# Interest Expense                           8.867261e+03  1.630516e+04
# Total Assets                               1.763840e+06  1.137969e+06
# ...

# %%
Y.analyze_REIT()
# Out:
# Analyzing Retail Sector's Financial Ratios
# Analyze Efficiency
# Tax  not found.
# Analyzing Liquidity Ratios
# Analyzing Solvency
# Tax  not found.
# Tax  not found.
# Analyzing Dividend Financial Ratios
# Dividend data found
# Analyzing Sales-related Financial Ratios
# No sales data available
# Analyze Inventory Holding
# No Stock data found.
# Other Income  not found.
# Other Income  not found.
# Other Income  not found.
# Other Income  not found.
# Other Income  not found.

# %%
Y.getFinancialRatios()
# Out:
#                       Financial Ratios       2020       2019       2018  \
# 0      EBITDA to Cash Conversion Ratio   1.079302   0.911594   0.945194
# 1             Revenue to Expense Ratio   2.079185   2.008129   1.850357
# 2                        Current Ratio   0.033836   0.022965   0.026528
# 3                           Cash Ratio   0.007235   0.008192   0.009131
# 4            Operating Cash Flow Ratio   0.060677   0.142107   0.121351
# 5                Cash Conversion Ratio   1.306326   1.215512   1.361947
# 6                           Debt Ratio   0.399142   0.335818   0.340015
# 7                 Debt to Equity Ratio   0.718171   0.542371   0.548623
# 8              Interest Coverage Ratio   4.743344   4.058742   3.311929
# 9                  Years to Repay Debt  16.738342   5.774538     7.0999
# 10               Average Interest Rate   0.012595   0.042667   0.042527
# 11                      Dividend Yield    0.07469   0.059545   0.052778
# ...

# %%
Y.writeOut("FR_Y_REIT")
