# %%
from financialRatiosModule.Sector_Retail import financialData_retail

# %%
X = financialData_retail("uniqueItemsFromAnnualReports_X_Retail", "Main", 0)
X.getInput()
# Out:
# Financial Data Object created
#                                                    2019          2018  \
# Items
# Gross Dividend Payout (Currency per Unit)  3.000000e-02  4.000000e-02
# Outstanding Shares                         1.404426e+09  1.401380e+09
# Unit Price (Currency)                      2.570000e+00  1.420000e+00
# Total Interest Paid                        3.659900e+04  1.677510e+05
# Trade Debtors                              7.680330e+05  8.777210e+05
# Trade Creditors                            5.147700e+04  2.640500e+04
# Sales                                      3.019156e+06  3.352845e+06
# Cash and Cash Equivalent                   8.148800e+04  6.698200e+04
# Free Cash Flow                            -1.093210e+05 -1.517200e+04
# Net Cash Flow from Financing               1.027610e+05 -4.338330e+05
# Net Cash Flow from Investments            -6.946500e+05 -2.704400e+05
# Net Cash Flow from Operations              4.825680e+05  6.891010e+05
# ...

# %%
X.analyze_retail()
# Out:
# Calculating Retail's Financial Ratios
# Analyzing Valuation
# Analyzing Profitability
# Analyze Efficiency
# Analyzing Liquidity Ratios
# Analyzing Solvency
# Analyzing Dividend Financial Ratios
# Dividend data found
# Analyzing Sales-related Financial Ratios
# Sales data available
# Analyze Inventory Holding
# Stock data found.

# %%
X.getFinancialRatios()
# Out:
#                    Financial Ratios       2019        2018       2017  \
# 0               Price to Book Ratio   1.938123    1.181904   1.268274
# 1           Price to Earnings Ratio  39.710592   18.207736  23.499426
# 2                  Return on Equity   0.048297    0.064454   0.053497
# 3        Return on Capital Employed   0.088108    0.088192   0.134854
# 4           EBITDA to Revenue Ratio   0.115419    0.186084   0.128612
# 5   EBITDA to Cash Conversion Ratio   1.040392    0.815879   0.732683
# 6          Revenue to Expense Ratio   1.105164    1.151643   1.134005
# 7                     Current Ratio   0.386837    0.360485   0.296352
# 8                        Cash Ratio   0.037535    0.027116   0.029931
# 9         Operating Cash Flow Ratio   0.222281    0.278963   0.146709
# 10            Cash Conversion Ratio   5.309246    6.305137    3.66866
# 11                       Debt Ratio   0.218725    0.142045   0.212645
# ...

# %%
X.writeOut("FR_X_Retail")

# %%
X.getFinancialRatios()
# Out:
#                                       2019        2018       2017       2016  \
# Financial Ratios
# Price to Book Ratio               1.938123    1.181904   1.268274    2.09248
# Price to Earnings Ratio          39.710592   18.207736  23.499426  29.020546
# Return on Equity                  0.048297    0.064454   0.053497   0.071813
# Return on Capital Employed        0.088108    0.088192   0.134854   0.116312
# EBITDA to Revenue Ratio           0.115419    0.186084   0.128612   0.116368
# EBITDA to Cash Conversion Ratio   1.040392    0.815879   0.732683   0.665242
# Revenue to Expense Ratio          1.105164    1.151643   1.134005   1.102995
# Current Ratio                     0.386837    0.360485   0.296352   0.445625
# Cash Ratio                        0.037535    0.027116   0.029931   0.102291
# Operating Cash Flow Ratio         0.222281    0.278963   0.146709   0.141988
# Cash Conversion Ratio             5.309246    6.305137    3.66866    2.25449
# ...
