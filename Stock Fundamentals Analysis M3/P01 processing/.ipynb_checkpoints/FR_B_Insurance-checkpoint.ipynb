# %%
from financialRatiosModule.Sector_Insurance import financialData_insurance

# %%
B = financialData_insurance("uniqueItemsFromAnnualReports_B_Insurance", "Main", 0)
B.getInput()
# Out:
# Financial Data Object created
#                                                    2020         2019  \
# Items
# Outstanding Shares                         3.319860e+08  398383000.0
# Free Cash Flow                            -6.215740e+05    -233381.0
# Cash and Cash Equivalent                   3.325170e+05     186188.0
# Net Cash Flow from Financing              -2.489890e+05    -281217.0
# Net Cash Flow from Investments            -2.833000e+03      -4256.0
# Net Cash Flow from Operations             -3.697520e+05      52092.0
# Current Assets                             3.325170e+05     186188.0
# Current Liabilities                        6.133220e+05     697884.0
# Intangible Assets                          0.000000e+00      10514.0
# Investment Assets                          1.187678e+06    1326171.0
# Total Assets                               3.656113e+06    4045890.0
# Total Debt                                 0.000000e+00          0.0
# ...

# %%
B.analyze_insurance()
# Out:
# Calculating Insurance's Financial Ratios
# Analyzing Valuation
# Analyzing Profitability
# Analyze Efficiency
# Analyzing Liquidity Ratios
# Analyzing Solvency
# Analyzing Dividend Financial Ratios
# Dividend data found
# Analyzing Sales-related Financial Ratios
# No sales data available
# Analyze Inventory Holding
# No Stock data found.
# Investment Expense  not found.
# Investment Expense  not found.

# %%
B.getFinancialRatios()
# Out:
#                    Financial Ratios       2020        2019           2018  \
# 0               Price to Book Ratio   2.959714    3.067008       3.138545
# 1           Price to Earnings Ratio  12.437431   18.661015      19.212814
# 2                  Return on Equity   0.237968    0.163477       0.163357
# 3        Return on Capital Employed   0.169746    0.123772       0.126041
# 4           EBITDA to Revenue Ratio   0.378917    0.267128       0.276709
# 5   EBITDA to Cash Conversion Ratio   -0.70768    0.121674       0.596471
# 6          Revenue to Expense Ratio   4.441591    4.315459       4.280902
# 7                     Current Ratio   0.542157    0.266789       0.466629
# 8                        Cash Ratio   0.542157    0.266789       0.466629
# 9         Operating Cash Flow Ratio  -0.602868    0.074643       0.384648
# 10            Cash Conversion Ratio  -0.845683    0.161595        0.77352
# 11                       Debt Ratio        0.0         0.0            0.0
# ...

# %%
B.writeOut("FR_B_Insurance")

# %%
B.getFinancialRatios()
# Out:
#                                       2020        2019           2018  \
# Financial Ratios
# Price to Book Ratio               2.959714    3.067008       3.138545
# Price to Earnings Ratio          12.437431   18.661015      19.212814
# Return on Equity                  0.237968    0.163477       0.163357
# Return on Capital Employed        0.169746    0.123772       0.126041
# EBITDA to Revenue Ratio           0.378917    0.267128       0.276709
# EBITDA to Cash Conversion Ratio   -0.70768    0.121674       0.596471
# Revenue to Expense Ratio          4.441591    4.315459       4.280902
# Current Ratio                     0.542157    0.266789       0.466629
# Cash Ratio                        0.542157    0.266789       0.466629
# Operating Cash Flow Ratio        -0.602868    0.074643       0.384648
# Cash Conversion Ratio            -0.845683    0.161595        0.77352
# Debt Ratio                             0.0         0.0            0.0
# ...
