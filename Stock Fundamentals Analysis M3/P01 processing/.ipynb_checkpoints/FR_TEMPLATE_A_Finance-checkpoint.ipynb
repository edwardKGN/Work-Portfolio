# %%
from financialRatiosModule.Sector_Finance import financialData_finance

# %%
A = financialData_finance("uniqueItemsFromAnnualReports_A_Finance", "Main", 0)
A.getInput()
# Out:
# Financial Data Object created
#                                                    2020          2019  \
# Items
# Cash and Cash Equivalent                   4.381345e+07  5.087575e+07
# Free Cash Flow                            -3.452016e+06 -3.270953e+06
# Net Cash Flow from Financing              -5.551653e+06 -7.695670e+05
# Net Cash Flow from Investment             -1.484780e+05 -3.888710e+05
# Net Cash Flow from Operations              2.248115e+06 -2.112515e+06
# Gross Dividend Payout (Currency per Unit)  5.200000e-01  5.200000e-01
# Outstanding Shares                         1.124137e+10  1.019317e+10
# Unit Price (Currency)                      8.460000e+00  8.200000e+00
# Interest Expense                           8.260375e+06  9.582029e+06
# Interest Income                            1.935076e+07  2.094050e+07
# Net Income                                 6.719079e+06  6.963892e+06
# Non-Interest Income                        2.289364e+07  1.480284e+07
# ...

# %%
A.analyze_finance()
# Out:
# Calculating Finance's Financial Ratios
# Analyzing Valuation
# Analyzing Profitability
# Analyze Efficiency
# Analyzing Liquidity Ratios
# Analyzing Dividend Financial Ratios
# Dividend data found
# Analyzing Sales-related Financial Ratios
# No sales data available
# Analyze Inventory Holding
# No Stock data found.

# %%
A.getFinancialRatios()
# Out:
#                       Financial Ratios       2020       2019       2018  \
# 0                  Price to Book Ratio   1.063054   1.324013   1.478085
# 1              Price to Earnings Ratio  14.154023  12.002484  12.562566
# 2                     Return on Equity   0.079575   0.101639   0.110924
# 3           Return on Capital Employed    0.06712    0.05014     0.0753
# 4              EBITDA to Revenue Ratio   0.610712   0.635551   0.666935
# 5      EBITDA to Cash Conversion Ratio   0.072135  -0.074431   0.336031
# 6             Revenue to Expense Ratio   2.616228   2.225198   2.115662
# 7                        Current Ratio     0.3677   0.463691   0.400402
# 8                           Cash Ratio   0.065939   0.101167   0.088902
# 9            Operating Cash Flow Ratio   0.003383  -0.004201   0.016516
# 10               Cash Conversion Ratio   0.334587  -0.303353   1.269146
# 11                      Dividend Yield   0.061466   0.063415       0.06
# ...

# %%
A.writeOut("FR_A_Finance")
