# %%
from financialRatiosModule.Sector_FinancialServices import financialData_financialServices

# %%
Bursa = financialData_financialServices("uniqueItemsFromAnnualReports_Bursa_FinancialServices.xlsx", "Main", 0)
Bursa.getInput()
# Out:
# Financial Data Object created
#                                                    2020          2019  \
# Items
# Outstanding Shares                         8.072289e+08  8.045977e+08
# Unit Price (Currency)                      8.300000e+00  6.090000e+00
# Gross Dividend Payout (Currency per Unit)  5.100000e-01  2.080000e-01
# Cash and Cash Equivalent                   2.865340e+05  1.854910e+05
# Free Cash Flow                             1.011030e+05  1.757100e+04
# Net Cash Flow from Financing              -2.256240e+05 -1.777560e+05
# Net Cash Flow from Investment             -9.051100e+04  8.699000e+03
# Net Cash Flow from Operations              4.172380e+05  1.866280e+05
# Current Assets                             2.772046e+06  1.854154e+06
# Current Liabilities                        2.304289e+06  1.530776e+06
# Fixed Assets                               1.641040e+05  1.669500e+05
# Intangible Assets                          7.628800e+04  8.289900e+04
# ...

# %%
Bursa.analyze_financialServices()
# Out:
# Analyzing Financial Service Sector's Financial Ratios
# Analyzing Valuation
# Analyzing Profitability
# Analyze Efficiency
# Analyzing Liquidity Ratios
# Analyzing Solvency
# Analyzing Dividend Financial Ratios
# Dividend data found
# Analyzing Sales-related Financial Ratios
# No sales data available
# Analyze Inventory Holding
# No Stock data found.

# %%
Bursa.getFinancialRatios()
# Out:
#                    Financial Ratios        2020        2019        2018  \
# 0               Price to Book Ratio    8.126068    7.228567    6.839563
# 1           Price to Earnings Ratio   17.736739   25.849608   23.849376
# 2                  Return on Equity    0.419348    0.249168    0.259862
# 3        Return on Capital Employed     0.54618    0.324321    0.336581
# 4           EBITDA to Revenue Ratio    0.678694    0.577077    0.631922
# 5   EBITDA to Cash Conversion Ratio    0.789371    0.673565    0.648027
# 6          Revenue to Expense Ratio    1.947835    1.643426    1.759434
# 7                     Current Ratio    1.202994    1.211251    1.201852
# 8                        Cash Ratio    0.124348    0.121174    0.110692
# 9         Operating Cash Flow Ratio     0.18107    0.121917    0.141224
# 10            Cash Conversion Ratio    1.104544    0.984543    0.929211
# 11                       Debt Ratio         0.0         0.0         0.0
# ...

# %%
Bursa.writeOut("FR_Bursa_financialServices")

# %%
Bursa.getFinancialRatios()
# Out:
#                                        2020        2019        2018  \
# Financial Ratios
# Price to Book Ratio                8.126068    7.228567    6.839563
# Price to Earnings Ratio           17.736739   25.849608   23.849376
# Return on Equity                   0.419348    0.249168    0.259862
# Return on Capital Employed          0.54618    0.324321    0.336581
# EBITDA to Revenue Ratio            0.678694    0.577077    0.631922
# EBITDA to Cash Conversion Ratio    0.789371    0.673565    0.648027
# Revenue to Expense Ratio           1.947835    1.643426    1.759434
# Current Ratio                      1.202994    1.211251    1.201852
# Cash Ratio                         0.124348    0.121174    0.110692
# Operating Cash Flow Ratio           0.18107    0.121917    0.141224
# Cash Conversion Ratio              1.104544    0.984543    0.929211
# Debt Ratio                              0.0         0.0         0.0
# ...
